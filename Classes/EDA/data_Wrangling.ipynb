# %%
import pandas as pd

data = {
    'Name':['Alice','Bob','Charlie','David'],
    'Age':[25,30,35,40],
    'Salary':[50000,60000,70000,80000],
    'Gender':['Female','Male','Male','Male']
}

df = pd.DataFrame(data)
df.head()
# Out:
#       Name  Age  Salary  Gender
# 0    Alice   25   50000  Female
# 1      Bob   30   60000    Male
# 2  Charlie   35   70000    Male
# 3    David   40   80000    Male

# %%
df.dtypes
# Out:
# Name      object
# Age        int64
# Salary     int64
# Gender    object
# dtype: object

# %%
#Data Extraction
df['Age']
df.iloc[0:2]
# Out:
#     Name  Age  Salary  Gender
# 0  Alice   25   50000  Female
# 1    Bob   30   60000    Male

# %% [markdown]
# Data Wrangling - The process of transforming the messy data into usable format

# %% [markdown]
# 1. data Acquisition - Loading data from various source

# %%
#csv , excel , API , databases
#df = pd.read_csv('')
#url = 'https://vcgdvgcvdgvcgdv.csv'

# %% [markdown]
# 2. Data Inspection - Inspecting the data to give some insights into the structure and completeness

# %%
df.head()
df.describe()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      int64
#  2   Salary  4 non-null      int64
#  3   Gender  4 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 260.0+ bytes

# %% [markdown]
# 3. Data Cleaning - Removing or correcting the missing values or duplicate values

# %%
#identify any null values
df.isnull().sum()

#This is to drop the duplicates
df_cleaned = df.drop_duplicates()
df_cleaned
# Out:
#       Name  Age  Salary  Gender
# 0    Alice   25   50000  Female
# 1      Bob   30   60000    Male
# 2  Charlie   35   70000    Male
# 3    David   40   80000    Male

# %% [markdown]
# 4. Data Transformation - Normalization, scaling, encoding and type conversion

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df['Age_Scaled'] = scaler.fit_transform(df[['Age']])
df
# Out:
#       Name  Age  Salary  Gender  Age_Scaled
# 0    Alice   25   50000  Female    0.000000
# 1      Bob   30   60000    Male    0.333333
# 2  Charlie   35   70000    Male    0.666667
# 3    David   40   80000    Male    1.000000

# %% [markdown]
# 5. Data Integration - combining data from different source

# %%
extra = pd.DataFrame({
    'Name':['Alice','Bob'],
    'Department': ['HR','Finance']
})

df_merged = pd.merge(df , extra , on='Name', how='left')
df_merged
# Out:
#       Name  Age  Salary  Gender  Age_Scaled Department
# 0    Alice   25   50000  Female    0.000000         HR
# 1      Bob   30   60000    Male    0.333333    Finance
# 2  Charlie   35   70000    Male    0.666667        NaN
# 3    David   40   80000    Male    1.000000        NaN

# %% [markdown]
# 6. Data Validation and Quality --> data is consistent, correct

# %%
df[df['Age'] < 0]
# Out:
# Empty DataFrame
# Columns: [Name, Age, Salary, Gender, Age_Scaled]
# Index: []

# %% [markdown]
# 7. Documentation and reporting - Describe your dataset, transformations and results clearly

# %%
report = df.describe(include='all')
report
# Out:
#          Name        Age        Salary Gender  Age_Scaled
# count       4   4.000000      4.000000      4    4.000000
# unique      4        NaN           NaN      2         NaN
# top     Alice        NaN           NaN   Male         NaN
# freq        1        NaN           NaN      3         NaN
# mean      NaN  32.500000  65000.000000    NaN    0.500000
# std       NaN   6.454972  12909.944487    NaN    0.430331
# min       NaN  25.000000  50000.000000    NaN    0.000000
# 25%       NaN  28.750000  57500.000000    NaN    0.250000
# 50%       NaN  32.500000  65000.000000    NaN    0.500000
# 75%       NaN  36.250000  72500.000000    NaN    0.750000
# max       NaN  40.000000  80000.000000    NaN    1.000000
