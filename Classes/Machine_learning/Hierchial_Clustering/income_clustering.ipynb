# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('/content/income.csv')
df.head()
# Out:
#       Name  Age  Income($)
# 0      Rob   27      70000
# 1  Michael   29      90000
# 2    Mohan   29      61000
# 3   Ismail   28      60000
# 4     Kory   42     150000

# %%
plt.scatter(df.Age,df['Income($)'])
plt.xlabel('Age')
plt.ylabel('Income')
plt.show()

# %%
scaler = StandardScaler()
df['Age'] = scaler.fit_transform(df[['Age']])

# %%
df.head()
# Out:
#       Name       Age  Income($)
# 0      Rob -1.356055      70000
# 1  Michael -1.009157      90000
# 2    Mohan -1.009157      61000
# 3   Ismail -1.182606      60000
# 4     Kory  1.245679     150000

# %%
df['Income($)'] = scaler.fit_transform(df[['Income($)']])

# %%
df.head()
# Out:
#       Name       Age  Income($)
# 0      Rob -1.356055  -0.480684
# 1  Michael -1.009157  -0.010159
# 2    Mohan -1.009157  -0.692421
# 3   Ismail -1.182606  -0.715947
# 4     Kory  1.245679   1.401417

# %%
import scipy.cluster.hierarchy as sch
df_new = df.loc[:,['Age','Income($)']]
dendrogram = sch.dendrogram(sch.linkage(df_new, method='ward'))
plt.xlabel('Income')
plt.ylabel('Distance')
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
model = AgglomerativeClustering(n_clusters=3,metric='euclidean',linkage='ward')
prediction = model.fit_predict(df_new)

# %%
from sklearn.metrics import silhouette_score

# %%
silhouette_score(df_new,prediction)
# Out:
# np.float64(0.7119890290065082)
