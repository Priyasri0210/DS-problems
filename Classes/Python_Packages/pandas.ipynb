# %% [markdown]
# *Pandas dataframe is a 2 dimensional tabular data structure with labels*
#
# Useful for Data processing and analysis

# %%
import pandas as pd
import numpy as np
#Dataframes

# %%
#load the csv dataset to dataframe
diabetes_df = pd.read_csv('/content/diabetes_prediction_dataset.csv')

# %%
#It prints 1st 5 rows
diabetes_df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
#load the excel dataset to dataframe
# diabetes_df = pd.read_excel('')

#load the json dataset to dataframe
# diabetes_df = pd.read_json('')

# %%
type(diabetes_df)
# Out:
# pandas.core.frame.DataFrame

# %%
#It prints last 5 rows
diabetes_df.tail()
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 99995          6.2                   90         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0

# %%
#information about the dataframe
diabetes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
#This function is used to get the total nulls in the column
diabetes_df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
#This function is used to fill the null values with some default values
# diabetes_df.fillna(0)

# %%
#counting the values based on column/label
diabetes_df.value_counts('diabetes')
# Out:
# diabetes
# 0    91500
# 1     8500
# Name: count, dtype: int64

# %%
diabetes_df['diabetes'].mean()
diabetes_df['diabetes'].mode()
diabetes_df['diabetes'].median()
# Out:
# 0.0

# %%
groups = diabetes_df.groupby('diabetes')
#mean median and mode it works only for numbers
#Remove the columns with strings or enlabel them to numbers

# %%
diabetes_df = diabetes_df.drop(columns = 'smoking_history', axis=1)
diabetes_df
# Out:
#        gender   age  hypertension  heart_disease    bmi  HbA1c_level  \
# 0      Female  80.0             0              1  25.19          6.6
# 1      Female  54.0             0              0  27.32          6.6
# 2        Male  28.0             0              0  27.32          5.7
# 3      Female  36.0             0              0  23.45          5.0
# 4        Male  76.0             1              1  20.14          4.8
# ...       ...   ...           ...            ...    ...          ...
# 99995  Female  80.0             0              0  27.32          6.2
# 99996  Female   2.0             0              0  17.37          6.5
# 99997    Male  66.0             0              0  27.83          5.7
# 99998  Female  24.0             0              0  35.42          4.0
# 99999  Female  57.0             0              0  22.43          6.6
#
#        blood_glucose_level  diabetes
# 0                      140         0
# 1                       80         0
# ...

# %%
diabetes_df['gender'] = np.where(diabetes_df['gender'] == 'Male',0,1)
diabetes_df
# Out:
#        gender   age  hypertension  heart_disease    bmi  HbA1c_level  \
# 0           1  80.0             0              1  25.19          6.6
# 1           1  54.0             0              0  27.32          6.6
# 2           0  28.0             0              0  27.32          5.7
# 3           1  36.0             0              0  23.45          5.0
# 4           0  76.0             1              1  20.14          4.8
# ...       ...   ...           ...            ...    ...          ...
# 99995       1  80.0             0              0  27.32          6.2
# 99996       1   2.0             0              0  17.37          6.5
# 99997       0  66.0             0              0  27.83          5.7
# 99998       1  24.0             0              0  35.42          4.0
# 99999       1  57.0             0              0  22.43          6.6
#
#        blood_glucose_level  diabetes
# 0                      140         0
# 1                       80         0
# ...

# %%
diabetes_df.groupby('diabetes').mean()
# Out:
#             gender        age  hypertension  heart_disease        bmi  \
# diabetes
# 0         0.591355  40.115187      0.058984       0.029235  26.887163
# 1         0.524824  60.946588      0.245647       0.149059  31.988382
#
#           HbA1c_level  blood_glucose_level
# diabetes
# 0            5.396761           132.852470
# 1            6.934953           194.094706

# %%
diabetes_df.mean()
# Out:
# gender                   0.585700
# age                     41.885856
# hypertension             0.074850
# heart_disease            0.039420
# bmi                     27.320767
# HbA1c_level              5.527507
# blood_glucose_level    138.058060
# diabetes                 0.085000
# dtype: float64

# %%
diabetes_df.std()
# Out:
# gender                  0.492603
# age                    22.516840
# hypertension            0.263150
# heart_disease           0.194593
# bmi                     6.636783
# HbA1c_level             1.070672
# blood_glucose_level    40.708136
# diabetes                0.278883
# dtype: float64

# %%
diabetes_df.min()
# Out:
# gender                  0.00
# age                     0.08
# hypertension            0.00
# heart_disease           0.00
# bmi                    10.01
# HbA1c_level             3.50
# blood_glucose_level    80.00
# diabetes                0.00
# dtype: float64

# %%
diabetes_df.max()
# Out:
# gender                   1.00
# age                     80.00
# hypertension             1.00
# heart_disease            1.00
# bmi                     95.69
# HbA1c_level              9.00
# blood_glucose_level    300.00
# diabetes                 1.00
# dtype: float64

# %%
diabetes_df.describe()
# Out:
#               gender            age  hypertension  heart_disease  \
# count  100000.000000  100000.000000  100000.00000  100000.000000
# mean        0.585700      41.885856       0.07485       0.039420
# std         0.492603      22.516840       0.26315       0.194593
# min         0.000000       0.080000       0.00000       0.000000
# 25%         0.000000      24.000000       0.00000       0.000000
# 50%         1.000000      43.000000       0.00000       0.000000
# 75%         1.000000      60.000000       0.00000       0.000000
# max         1.000000      80.000000       1.00000       1.000000
#
#                  bmi    HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000  100000.000000        100000.000000  100000.000000
# mean       27.320767       5.527507           138.058060       0.085000
# std         6.636783       1.070672            40.708136       0.278883
# min        10.010000       3.500000            80.000000       0.000000
# ...

# %%
#adding new column
diabetes_df['Dummy'] = 0
diabetes_df
# Out:
#        gender   age  hypertension  heart_disease    bmi  HbA1c_level  \
# 0           1  80.0             0              1  25.19          6.6
# 1           1  54.0             0              0  27.32          6.6
# 2           0  28.0             0              0  27.32          5.7
# 3           1  36.0             0              0  23.45          5.0
# 4           0  76.0             1              1  20.14          4.8
# ...       ...   ...           ...            ...    ...          ...
# 99995       1  80.0             0              0  27.32          6.2
# 99996       1   2.0             0              0  17.37          6.5
# 99997       0  66.0             0              0  27.83          5.7
# 99998       1  24.0             0              0  35.42          4.0
# 99999       1  57.0             0              0  22.43          6.6
#
#        blood_glucose_level  diabetes  Dummy
# 0                      140         0      0
# 1                       80         0      0
# ...

# %%
#Dropping the row
diabetes_df.drop(index=0, axis=0)
# Out:
#        gender   age  hypertension  heart_disease    bmi  HbA1c_level  \
# 1           1  54.0             0              0  27.32          6.6
# 2           0  28.0             0              0  27.32          5.7
# 3           1  36.0             0              0  23.45          5.0
# 4           0  76.0             1              1  20.14          4.8
# 5           1  20.0             0              0  27.32          6.6
# ...       ...   ...           ...            ...    ...          ...
# 99995       1  80.0             0              0  27.32          6.2
# 99996       1   2.0             0              0  17.37          6.5
# 99997       0  66.0             0              0  27.83          5.7
# 99998       1  24.0             0              0  35.42          4.0
# 99999       1  57.0             0              0  22.43          6.6
#
#        blood_glucose_level  diabetes  Dummy
# 1                       80         0      0
# 2                      158         0      0
# ...

# %%
#get the values based on index

# %%
diabetes_df.iloc[2]
# Out:
# gender                   0.00
# age                     28.00
# hypertension             0.00
# heart_disease            0.00
# bmi                     27.32
# HbA1c_level              5.70
# blood_glucose_level    158.00
# diabetes                 0.00
# Dummy                    0.00
# Name: 2, dtype: float64

# %%
diabetes_df.query('gender == 0 and diabetes == 1')
# Out:
#        gender   age  hypertension  heart_disease    bmi  HbA1c_level  \
# 26          0  67.0             0              1  27.32          6.5
# 38          0  50.0             1              0  27.32          5.7
# 40          0  73.0             0              0  25.91          9.0
# 55          0  50.0             0              0  37.16          9.0
# 81          0  57.0             0              0  27.32          8.2
# ...       ...   ...           ...            ...    ...          ...
# 99826       0  63.0             0              1  27.32          6.6
# 99829       0  58.0             0              0  32.38          6.6
# 99867       0  64.0             1              0  33.12          5.7
# 99897       0  67.0             0              0  27.32          6.8
# 99938       0  55.0             0              1  30.42          6.2
#
#        blood_glucose_level  diabetes  Dummy
# 26                     200         1      0
# 38                     260         1      0
# ...

# %%
diabetes_df.loc[(diabetes_df['gender'] == 0) & (diabetes_df['diabetes'] == 1)]
# Out:
#        gender   age  hypertension  heart_disease    bmi  HbA1c_level  \
# 26          0  67.0             0              1  27.32          6.5
# 38          0  50.0             1              0  27.32          5.7
# 40          0  73.0             0              0  25.91          9.0
# 55          0  50.0             0              0  37.16          9.0
# 81          0  57.0             0              0  27.32          8.2
# ...       ...   ...           ...            ...    ...          ...
# 99826       0  63.0             0              1  27.32          6.6
# 99829       0  58.0             0              0  32.38          6.6
# 99867       0  64.0             1              0  33.12          5.7
# 99897       0  67.0             0              0  27.32          6.8
# 99938       0  55.0             0              1  30.42          6.2
#
#        blood_glucose_level  diabetes  Dummy
# 26                     200         1      0
# 38                     260         1      0
# ...

# %%
#df.loc[df[condition_column] == 10 , 'column'] = new value
diabetes_df.loc[diabetes_df['age'] == 10 , 'age'] = 20

# %%
#exporting the dataframe to file
diabetes_df.to_csv('sample.csv')
